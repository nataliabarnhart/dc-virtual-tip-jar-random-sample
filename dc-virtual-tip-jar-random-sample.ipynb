# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# Import everything from the Google spreadsheet
url = 'https://docs.google.com/spreadsheets/d/1tz2uyhgy3MsBS68MHPzO8H455_879fqfIaRPyUUw3QE/htmlview?sle=true#gid=0'
response = requests.get(url)

# Find and parse the table
soup = BeautifulSoup(response.text, "html.parser")
table = soup.find_all('table')

# %%
# Convert the HTML table to a dataframe
df1 = pd.read_html(str(table), header=0, flavor='html5lib')[0]
# df1.head()

# %%
# Clean up the dataframe
header = df1.iloc[2]
df2 = df1[4:]
df2.columns = header
df3 = df2.drop(columns=[3.0])
df4 = df3.dropna(axis='columns', how='all')
df4 = df4.reset_index(drop=True)
# df5 = df4.replace(np.nan, '', regex=True)
df4 = df4.rename_axis('#', axis='columns')
# df4.head()
# Out:
# #   Restaurant/Bar/Club   Server/Bartender             Venmo  \
# 0                &pizza         Diamone Co  @Diamante_Coll22
# 1            12 Stories       Ken Matthews      @irunthisbar
# 2        12 Stories Bar          Dani Cole               NaN
# 3        12 Stories Bar      Daniella Cole               NaN
# 4  1310 kitchen and bar  Wilfredo castillo               NaN
#
# # Paypal or Cash App Do you have healthcare?
# 0                NaN                     Yes
# 1                NaN                      No
# 2             PayPal                     NaN
# 3              Papal                     NaN
# 4            Cashapp                      No

# %%
# Show a random sample of 5

df5 = df4.replace(np.nan, '', regex=True)
df5.sample(5)
# Out:
# #    Restaurant/Bar/Club   Server/Bartender              Venmo  \
# 1403   Pizzeria Paradiso  Camilo Rosenblatt  @CamiloRosenblatt
# 1453  Public bar live DC    JESUS ALVARENGA
# 724               El Rey        Trei Ramsey       @Trei-Ramsey
# 1865        The Hamilton   Princess Johnson
# 218            Black Cat       Laura Harris
#
# #                            Paypal or Cash App Do you have healthcare?
# 1403                                                                 No
# 1453                           Ayala22@live.com                      No
# 724
# 1865                 Johnson.princess@ymail.com                     Yes
# 218   Laurajeanharris@gmail.com (Ricky Records)                      No

# %%
# Only sample people with a Venmo

df6 = df4.dropna(subset=['Venmo'])
df6 = df6.replace(np.nan, '', regex=True)
df6.sample(5)
# Out:
# #     Restaurant/Bar/Club Server/Bartender             Venmo  \
# 291             Breadsoda   Caleb Marindin   @caleb-marindin
# 733    Elder Pine brewing     Jay Anderson  @Jay-Anderson-89
# 1172  Matchbox Restaurant   Blake Rodevick      @VickQuinter
# 1588              Room 11     Gavin Pierce     @gavinkpierce
# 1040              Kinship    Luis Ladislao    @Luis-Ladislao
#
# #    Paypal or Cash App Do you have healthcare?
# 291                                          No
# 733                                          No
# 1172                                        Yes
# 1588
# 1040                                         No

# %%
# Only sample people with a Paypal or Cash App

df7 = df4.dropna(subset=['Paypal or Cash App'])
df7 = df7.replace(np.nan, '', regex=True)
df7.sample(5)
# Out:
# #     Restaurant/Bar/Club Server/Bartender          Venmo  \
# 1748       TAP SPORTS BAR       Sean Jones
# 830      Founding farmers     Kwasi Ashton
# 1735  Swings Coffee Roast  Cherrise Capers
# 1276         NEPTUNE ROOM     Joy Atherton  @Joy-Atherton
# 942           Inari salon   Santos sanchez
#
# #            Paypal or Cash App Do you have healthcare?
# 1748                 $godsun420                     Yes
# 830                $KwasiAshton                      No
# 1735  cash app: $CherriseCapers
# 1276      PayPal.Me/joyatherton                     Yes
# 942         Cash app $santos921                      No

# %%
# Only sample people with no healthcare

df8 = df4.loc[df4['Do you have healthcare?'] == 'No']
df8 = df8.replace(np.nan, '', regex=True)
df8.sample(5)
# Out:
# #        Restaurant/Bar/Club Server/Bartender              Venmo  \
# 1256              Mr Henry’s       Cathy Nagy  @Catherine-Nagy-1
# 1905  The Park at Fourteenth      Neil Torres         @neileneil
# 1794    The Canopy By Hilton   Sarina Dockett    @Sarina-Dockett
# 132              Bantam King      Jordan Bond     @Jordan-Bond-8
# 1715            Stadium Club     Jess Whyland
#
# #        Paypal or Cash App Do you have healthcare?
# 1256                                             No
# 1905                                             No
# 1794        @Sarina-Dockett                      No
# 132                                              No
# 1715  jesswhyland@gmail.com                      No
